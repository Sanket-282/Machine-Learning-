# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error, r2_score

# Load the data
data = pd.read_csv('Position_Salaries.csv')
X = data.iloc[:, 1:2].values  # Level column
y = data.iloc[:, 2].values    # Salary column


# Simple Linear Regression
linreg = LinearRegression()
linreg.fit(X, y)

# Polynomial Regression
polyreg = PolynomialFeatures(degree=4)
X_poly = polyreg.fit_transform(X)

polylinreg = LinearRegression()
polylinreg.fit(X_poly, y)

# Evaluate models
ypredlinearfull = linreg.predict(X)
ypredpolyfull = polylinreg.predict(polyreg.transform(X))


mse_linear = mean_squared_error(y, ypredlinearfull)
mse_poly = mean_squared_error(y, ypredpolyfull)

r2_linear = r2_score(y, ypredlinearfull)
r2_poly = r2_score(y, ypredpolyfull)

print("Linear Regression MSE:",mse_linear)
print("Linear Regression R2 square:",r2_linear)
print("Polynomial Regression MSE:", mse_poly)
print("Polynomial Regression R2 square:", r2_poly)

# Predicting the salaries for levels 11 and 12
Xpred = np.array([[11], [12]])
ypredlinear = linreg.predict(X_pred)
ypredpoly = polylinreg.predict(polyreg.transform(X_pred))

# Print predictions
print("Linear Regression Predictions for levels 11 and 12:",ypredlinear)
print("Polynomial Regression Predictions for levels 11 and 12:",ypredpoly)


# Visualizing the results
plt.scatter(X, y, color='red')
plt.plot(X, ypredlinearfull, color='blue', label='Linear Regression')
plt.plot(X, ypredpolyfull, color='green', label='Polynomial Regression')
plt.title('Salary vs Level')
plt.xlabel('Level')
plt.ylabel('Salary')
plt.legend()
plt.show()
# Out:
# Linear Regression Predictions for levels 11 and 12: [694333.33333333 775212.12121212]
# Polynomial Regression Predictions for levels 11 and 12: [1780833.33333322 3035984.84848502]
# Linear Regression MSE: 26695878787.878784, R2: 0.6690412331929895
# Polynomial Regression MSE: 210343822.8438203, R2: 0.9973922891706614
